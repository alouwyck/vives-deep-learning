# %% [markdown]
# <a href="https://colab.research.google.com/github/alouwyck/vives-deep-learning/blob/main/topic2/Oefeningen_Gradient_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="data:image/png;base64,..." align="right" /><br>
#
#
# **DEEP LEARNING**<br>
# Academiejaar 2024-2025<br>
# Andy Louwyck
#
# ---
#
#
#
# ---

# %% [markdown]
# # **OEFENINGEN GRADIENT DESCENT**

# %% [markdown]
# ## **OEFENING 1**

# %% [markdown]
# ### OPGAVE

# %% [markdown]
# Hieronder zie je een schema van een stuk karton dat volgens de stippellijnen gevouwen wordt tot een doos met een deksel. Bepaal **x** zodat het volume van de doos zo groot mogelijk is. Neem **B** = 30 cm en **L** = 50 cm. Maak gebruik van het Gradient Descent algoritme en de optie in TensorFlow om automatisch te differentiëren, maar gebruik geen ingebouwde optimizer!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **OEFENING 2**

# %% [markdown]
# ### OPGAVE

# %% [markdown]
# Hieronder zie je een afbeelding van een driehoekig dak waarin een rechthoekig venster moet geplaatst worden waarvan de oppervlakte zo groot mogelijk moet zijn. Het venster rust op de basis van het dak en zit mooi in het midden. De bovenste hoeken van het venster komen tot tegen de schuine wanden van het dak. De basis van het dak is 20 m breed, de hoogte van het dak is 5 m. Bepaal de maximale oppervlakte van het venster m.b.v. het Gradient Descent algoritme.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# De volgende tip uit de driehoeksmeetkunde moet je op weg helpen:

# %% [markdown]
# ![image.png](data:image/png;base64,...)
