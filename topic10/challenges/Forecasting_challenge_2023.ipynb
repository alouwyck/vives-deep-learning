# %% [markdown]
# <a href="https://colab.research.google.com/github/alouwyck/vives-deep-learning/blob/main/topic10/challenges/Forecasting_challenge_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="data:image/png;base64,..." align="right" /><br>
#
#
# **DEEP LEARNING**<br>
# Academiejaar 2023-2024<br>
# Andy Louwyck
#
# ---
#
#
#
# ---

# %% [markdown]
# # **FORECASTING CHALLENGE**

# %% [markdown]
# Lees de dataset in die is opgeslagen in de file `"Ukkel_waarnemingen_okt_nov_2023.txt"`. Het gaat om meteorologische gegevens van de periode 2/10/2023 t.e.m. 30/11/2023 die zijn gemeten in het weerstation van het KMI in Ukkel (België). De data werden op 1/12/2023 gedownload van de website van het KMI: https://www.meteo.be/nl/klimaat/klimaat-van-belgie/recente-waarnemingen-te-ukkel.
#
# Train een RNN model dat de gemiddelde temperatuur (`"Temp_gem"`) voorspelt in Ukkel op 1/12/2023 o.b.v. de gegeven dataset. Met RNN wordt bedoeld een Keras model dat bestaat uit `SimpleRNN`, `LSTM` en/of `GRU` units. Je hoeft de dataset niet op te splitsen en mag dus de volledige tijdsreeks gebruiken om je model te trainen.
#
# De winnaar is diegene wiens model een gemiddelde temperatuur voorspelt die het dichtst ligt bij de gemiddelde temperatuur van 1/12/2023 zoals die in Ukkel werd waargenomen door het KMI. De evaluatie zal gebeuren adhv de mean absolute error (MAE).

# %% [markdown]
# ## **Oplossing**

# %% [markdown]
# Gebruik deze sectie om de data te preprocessen en je model te trainen en te evalueren.

# %% [markdown]
# ## **Voorspelling voor 1 dec**

# %% [markdown]
# Schrijf hier de code om ahdv je RNN de gemiddelde temperatuur te voorspellen voor 1 december. Ken die waarde toe aan variable `voorspelling`. Vergeet niet om terug om te zetten naar de juiste eenheid als je normalisatie of herschaling hebt toegepast!

# %% [markdown]
# Print je resultaat duidelijk uit tot op 2 cijfers na de komma aan de hand van het volgende statement:

# %%
print(f"De voorspelde temperatuur op 1 december is {voorspelling:.2f}°C")

# %% [markdown]
# ## **De echte gemiddelde temperatuur op 1 dec 2023**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
